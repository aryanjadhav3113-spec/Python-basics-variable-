# %% [markdown]
# Python Variable

# %%
1)String (str) = words or text inside quotes
ex:name="Aryan"

# %%
2)Integer (int) = whole Number
ex:age=16

# %%
3)Float (float) = Decimal Number
ex:Height=6.1

# %%
4)Boolean (bool) = True or False values
ex:is_student=True

# %%
5)List = A group of items inside square brackets
ex: fruits=["apple","mango","banana"]

# %%
6)Tuple = A fixed group of items inside parenthese.
ex:days=("mon","tue","wed")

# %%
7)Dictionary (dict) = Key values pairs inside curly braces.
ex:student={"name":"aryan","age":16}

# %%
8)Checking variable type code:
print(type(x))

# %% [markdown]
# # BOOLEAN (FALSE)

# %% [markdown]
# EX

# %%
3>8
# Out:
# False

# %%
5==12
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool(0)
# Out:
# False

# %% [markdown]
# # BOOLEAN (TRUE)

# %% [markdown]
# EX

# %%
5<432
# Out:
# True

# %%
65>54
# Out:
# True

# %%
23==23
# Out:
# True

# %%
bool(1)
# Out:
# True

# %% [markdown]
# # NONE

# %%
x="none"
print("x")
# Out:
# x

# %%
bool("none")
# Out:
# True

# %%
def greet():
    return "aryan"

result = greet()
print(result)
# Out:
# aryan

# %%
a="none"
print("empty")
# Out:
# empty

# %%
print(bool("none"))
# Out:
# True

# %%
a="none"
print("yes")
# Out:
# yes

# %% [markdown]
# # AND

# %%
5>2 & 10>3
# Out:
# False

# %%
5>2 & 10<3
# Out:
# True

# %%
age = 18
marks = 75

if age >= 18 and marks > 60:
    print("elizable")
# Out:
# elizable

# %%
print("true" and "fasle")
# Out:
# fasle

# %%
print("true" and "true")
# Out:
# true

# %%
print("false" and "true")
# Out:
# true

# %%
print("fasle" and "fasle")
# Out:
# fasle

# %%
10>3 and 5>1
# Out:
# True

# %%
7==7 & 8<2
# Out:
# False

# %% [markdown]
# # NOT

# %%
a = "true"
print(not  a)
# Out:
# False

# %%
b = "false"
print(not b)
# Out:
# False

# %%
# Out:
# True
# False

# %%
print("not fasle")
# Out:
# not fasle
